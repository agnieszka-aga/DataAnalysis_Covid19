# %% [markdown]
# # Covid-19 project: Data preparation (part 1)

# %%
# Import packages

import pandas as pd
import numpy as np

# %% [markdown]
# <b>Accessing data from the John Hopkins University </b>
# <br>
# Source: COVID-19 Data Repository by the Center for Systems Science and Engineering (CSSE) at Johns Hopkins University <br>
# https://github.com/CSSEGISandData/COVID-19

# %%
## Load data
updated_data_confirmed = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv")
updated_data_deaths = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv")
updated_data_recovered = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv")

## Save data to csv-file
updated_data_confirmed.to_csv("C:/Users/Agnieszka/Downloads/Datasets/Covid_temp/data_confirmed.csv", index=False)
updated_data_deaths.to_csv("C:/Users/Agnieszka/Downloads/Datasets/Covid_temp/data_deaths.csv", index=False)
updated_data_recovered.to_csv("C:/Users/Agnieszka/Downloads/Datasets/Covid_temp/data_recovered.csv", index=False)

## Read saved csv-files
confirmed_global = pd.read_csv("C:/Users/Agnieszka/Downloads/Datasets/Covid_temp/data_confirmed.csv")
deaths_global = pd.read_csv("C:/Users/Agnieszka/Downloads/Datasets/Covid_temp/data_deaths.csv")
recovered_global = pd.read_csv("C:/Users/Agnieszka/Downloads/Datasets/Covid_temp/data_recovered.csv")

confirmed_global.shape
# Output: (273, 387) -> 08.02.2021
confirmed_global.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  1/29/21  1/30/21  1/31/21  2/1/21  \
# 0        0        0        0        0  ...    54939    55008    55023   55059
# 1        0        0        0        0  ...    76350    77251    78127   78992
# 2        0        0        0        0  ...   106887   107122   107339  107578
# 3        0        0        0        0  ...     9837     9885     9937    9972
# 4        0        0        0        0  ...    19723    19782    19796   19829
#
#    2/2/21  2/3/21  2/4/21  2/5/21  2/6/21  2/7/21
# ...

# %%
deaths_global.shape
# Output: (273, 387) -> 08.02.2021
deaths_global.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  1/29/21  1/30/21  1/31/21  2/1/21  \
# 0        0        0        0        0  ...     2399     2400     2400    2404
# 1        0        0        0        0  ...     1358     1369     1380    1393
# 2        0        0        0        0  ...     2884     2888     2891    2894
# 3        0        0        0        0  ...      100      101      101     101
# 4        0        0        0        0  ...      464      464      466     466
#
#    2/2/21  2/3/21  2/4/21  2/5/21  2/6/21  2/7/21
# ...

# %%
#recovered_global.shape
# Output: (258, 387) -> less countries provide information on recovered patients? See below
recovered_global.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  1/29/21  1/30/21  1/31/21  2/1/21  \
# 0        0        0        0        0  ...    47606    47609    47679   47723
# 1        0        0        0        0  ...    46420    46927    47424   47922
# 2        0        0        0        0  ...    72956    73152    73344   73530
# 3        0        0        0        0  ...     8986     9045     9093    9206
# 4        0        0        0        0  ...    17918    18015    18035   18180
#
#    2/2/21  2/3/21  2/4/21  2/5/21  2/6/21  2/7/21
# ...

# %% [markdown]
# <b> Check on NaN values </b>

# %%
deaths_global.info(verbose=True, null_counts=True)
# Province/State: 84 non-null -> countries divided into provinces
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273 entries, 0 to 272
# Data columns (total 387 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  84 non-null     object
#  1   Country/Region  273 non-null    object
#  2   Lat             272 non-null    float64
#  3   Long            272 non-null    float64
#  4   1/22/20         273 non-null    int64
#  5   1/23/20         273 non-null    int64
#  6   1/24/20         273 non-null    int64
#  7   1/25/20         273 non-null    int64
#  8   1/26/20         273 non-null    int64
#  9   1/27/20         273 non-null    int64
#  10  1/28/20         273 non-null    int64
#  11  1/29/20         273 non-null    int64
#  12  1/30/20         273 non-null    int64
#  13  1/31/20         273 non-null    int64
#  14  2/1/20          273 non-null    int64
#  15  2/2/20          273 non-null    int64
#  16  2/3/20          273 non-null    int64
# ...

# %%
confirmed_global.info(verbose=True, null_counts=True)
# Province/State: 84 non-null -> countries divided into provinces
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273 entries, 0 to 272
# Data columns (total 387 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  84 non-null     object
#  1   Country/Region  273 non-null    object
#  2   Lat             272 non-null    float64
#  3   Long            272 non-null    float64
#  4   1/22/20         273 non-null    int64
#  5   1/23/20         273 non-null    int64
#  6   1/24/20         273 non-null    int64
#  7   1/25/20         273 non-null    int64
#  8   1/26/20         273 non-null    int64
#  9   1/27/20         273 non-null    int64
#  10  1/28/20         273 non-null    int64
#  11  1/29/20         273 non-null    int64
#  12  1/30/20         273 non-null    int64
#  13  1/31/20         273 non-null    int64
#  14  2/1/20          273 non-null    int64
#  15  2/2/20          273 non-null    int64
#  16  2/3/20          273 non-null    int64
# ...

# %%
recovered_global.info(verbose=True, null_counts=True)
# Province/State: 68 non-null -> countries divided into provinces
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258 entries, 0 to 257
# Data columns (total 387 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  68 non-null     object
#  1   Country/Region  258 non-null    object
#  2   Lat             258 non-null    float64
#  3   Long            258 non-null    float64
#  4   1/22/20         258 non-null    int64
#  5   1/23/20         258 non-null    int64
#  6   1/24/20         258 non-null    int64
#  7   1/25/20         258 non-null    int64
#  8   1/26/20         258 non-null    int64
#  9   1/27/20         258 non-null    int64
#  10  1/28/20         258 non-null    int64
#  11  1/29/20         258 non-null    int64
#  12  1/30/20         258 non-null    int64
#  13  1/31/20         258 non-null    int64
#  14  2/1/20          258 non-null    int64
#  15  2/2/20          258 non-null    int64
#  16  2/3/20          258 non-null    int64
# ...

# %%
# NaN values are only in the first column "Province/State" -> some countries are divided into provinces?

# %% [markdown]
# Checking if all countries appear in each table

# %%
recovered_global["Country/Region"].unique().shape
# Out:
# (192,)

# %%
confirmed_global["Country/Region"].unique().shape
# Out:
# (192,)

# %%
deaths_global["Country/Region"].unique().shape
# Out:
# (192,)

# %% [markdown]
# Checking which countries appear more than once and how many times

# %%
# check_multiple = confirmed_global.iloc[:,0:2]
check_multiple = deaths_global.iloc[:,0:2]
#check_multiple = recovered_global.iloc[:,0:2]

check_multiple.dropna(axis=0, inplace=True)

check_multiple.groupby(["Country/Region"]).count()
# Out:
#                 Province/State
# Country/Region
# Australia                    8
# Canada                      16
# China                       33
# Denmark                      2
# France                      11
# Netherlands                  4
# United Kingdom              10

# %% [markdown]
# Canada appears only once in "recovered" dataframe -> this is probably the country that is not devided into provinces in this dataframe
# <br>
# Let's check:

# %%
mask = recovered_global["Country/Region"] == "Canada"
recovered_global[mask]
# Out:
#    Province/State Country/Region      Lat      Long  1/22/20  1/23/20  \
# 39            NaN         Canada  56.1304 -106.3468        0        0
#
#     1/24/20  1/25/20  1/26/20  1/27/20  ...  1/29/21  1/30/21  1/31/21  \
# 39        0        0        0        0  ...   701306   706285   710699
#
#     2/1/21  2/2/21  2/3/21  2/4/21  2/5/21  2/6/21  2/7/21
# 39  718049  722002  726258  729768  726095  729371  732688
#
# [1 rows x 387 columns]

# %%
# Canada appears only once in "recovered" dataset

# %% [markdown]
# Countries that are divided into provinces: Australia, Canada (except: "recovered" dataframe), China <br>
# Overseas territories in case of: Denmark, France, Netherlands, United Kingdom <br>
# <br>
# In the next steps, the sum of all provinces will be calculated for each country and only the sum will remain in the dataset <br>
# In case of the overseas territories, values within "Country/Region" column will be replaced with "Province/State" values -> Country names will be replaced with names of its dependencies / overseas territories

# %% [markdown]
# <b> Dataset preparation </b>

# %% [markdown]
# Overseas territories

# %%
# Changing the name of Country/Region in case of overseas territories

def rename(df):
    
    overseas_terr=["Netherlands", "United Kingdom", "Denmark", "France"]
    for country in overseas_terr: 
        df["Country/Region"] = np.where((df["Country/Region"] == country) & (df["Province/State"].notna()), df["Province/State"], df["Country/Region"])
    return df

# %%
deaths_global_renamed = rename(deaths_global)
deaths_global_renamed.tail(12)
# Out:
#                Province/State            Country/Region        Lat  \
# 261                Montserrat                Montserrat  16.742498
# 262  Turks and Caicos Islands  Turks and Caicos Islands  21.694000
# 263                       NaN            United Kingdom  55.378100
# 264                       NaN                   Uruguay -32.522800
# 265                       NaN                Uzbekistan  41.377491
# 266                       NaN                   Vanuatu -15.376700
# 267                       NaN                 Venezuela   6.423800
# 268                       NaN                   Vietnam  14.058324
# 269                       NaN        West Bank and Gaza  31.952200
# 270                       NaN                     Yemen  15.552727
# 271                       NaN                    Zambia -13.133897
# 272                       NaN                  Zimbabwe -19.015438
#
#            Long  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  \
# ...

# %%
confirmed_global_renamed = rename(confirmed_global)
confirmed_global_renamed.tail(12)
# Out:
#                Province/State            Country/Region        Lat  \
# 261                Montserrat                Montserrat  16.742498
# 262  Turks and Caicos Islands  Turks and Caicos Islands  21.694000
# 263                       NaN            United Kingdom  55.378100
# 264                       NaN                   Uruguay -32.522800
# 265                       NaN                Uzbekistan  41.377491
# 266                       NaN                   Vanuatu -15.376700
# 267                       NaN                 Venezuela   6.423800
# 268                       NaN                   Vietnam  14.058324
# 269                       NaN        West Bank and Gaza  31.952200
# 270                       NaN                     Yemen  15.552727
# 271                       NaN                    Zambia -13.133897
# 272                       NaN                  Zimbabwe -19.015438
#
#            Long  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  \
# ...

# %%
recovered_global_renamed = rename(recovered_global)
recovered_global_renamed.tail(12)
# Out:
#                Province/State            Country/Region        Lat  \
# 246                Montserrat                Montserrat  16.742498
# 247  Turks and Caicos Islands  Turks and Caicos Islands  21.694000
# 248                       NaN            United Kingdom  55.378100
# 249                       NaN                   Uruguay -32.522800
# 250                       NaN                Uzbekistan  41.377491
# 251                       NaN                   Vanuatu -15.376700
# 252                       NaN                 Venezuela   6.423800
# 253                       NaN                   Vietnam  14.058324
# 254                       NaN        West Bank and Gaza  31.952200
# 255                       NaN                     Yemen  15.552727
# 256                       NaN                    Zambia -13.133897
# 257                       NaN                  Zimbabwe -19.015438
#
#            Long  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  \
# ...

# %%
# Check if the replacement was correct

check_multiple = confirmed_global.iloc[:,0:2]

check_multiple.dropna(axis=0, inplace=True)

check_multiple.groupby(["Country/Region"]).count()

check_multiple_replacement = check_multiple.groupby(["Country/Region"]).count() 
check_multiple_replacement
# Out:
#                                   Province/State
# Country/Region
# Anguilla                                       1
# Aruba                                          1
# Australia                                      8
# Bermuda                                        1
# Bonaire, Sint Eustatius and Saba               1
# British Virgin Islands                         1
# Canada                                        16
# Cayman Islands                                 1
# Channel Islands                                1
# China                                         33
# Curacao                                        1
# Falkland Islands (Malvinas)                    1
# Faroe Islands                                  1
# French Guiana                                  1
# French Polynesia                               1
# Gibraltar                                      1
# Greenland                                      1
# Guadeloupe                                     1
# ...

# %% [markdown]
# Countries divided into provinces

# %%
# For countries divided into provinces the number of cases will be summed up

mask = check_multiple_replacement["Province/State"] > 1
multiple_countries = check_multiple_replacement[mask]
multiple_countries
# Out:
#                 Province/State
# Country/Region
# Australia                    8
# Canada                      16
# China                       33

# %% [markdown]
# Function for summing up cases from all provinces for each country (Australia, China, Canada)

# %%
# Function for summing up cases from all provinces 
# automatically for each country

# Selects countries with duplicates (countries which are devided into regions) and calculate a sum of cases

def sum_country(df):
    
    column_names = list(multiple_countries.index.values)
    sum_pro_country =[]
    for country in column_names:
        
        # Select rows with duplicates (countries which are devided into regions)
        mask = df["Country/Region"] == str(country)
        df_mask = df[mask]
        #return df_mask
    
        # Drop first few columns, leave only columns with number of cases
        df_data = df_mask.drop(columns=['Province/State', 'Country/Region', 'Lat', 'Long'], axis=0)
    
        # Reset index and create new one with number of rows
        ## Define index values(h)
        h = np.arange(len(df_data.values))
        df_data.reset_index()
        df_data2 = df_data.set_index(h)
        # return df_data2
 
        # Transpose dataframe to make summing easier
        df_data2_trans = df_data2.transpose()
    
        # Sum up data from each row and for each day, and store results in "m" (sum for each country stored as a list)
        m=[]
        c=0
        for c in range(len(df_data2_trans)): 
            x = df_data2.iloc[0:h[-1]+1, c].sum()
            c = c + 1
            m.append(x)
        #return m
        
        # Store results for each country in "sum_pro_country"        
        sum_pro_country.append(m)  
    
    # Convert results into a dataframe to use "to_list()" function
    sum_pro_country2 = pd.DataFrame([sum_pro_country]).transpose()
    
    # Split the lists in column "0" which include all data points as a list (comes from "m")
    # to get dataframes with country name as an index and dates as column names
    end_result = pd.DataFrame(sum_pro_country2[0].to_list(), columns=df_data2.columns, index=multiple_countries.index.values)
    
    return end_result

# %% [markdown]
# Sum for each dataset and each country:

# %%
# Sum for each dataset
sum_deaths_global = sum_country(deaths_global)
sum_deaths_global
# Out:
#            1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Australia        0        0        0        0        0        0        0
# Canada           0        0        0        0        0        0        0
# China           17       18       26       42       56       82      131
#
#            1/29/20  1/30/20  1/31/20  ...  1/29/21  1/30/21  1/31/21  2/1/21  \
# Australia        0        0        0  ...      909      909      909     909
# Canada           0        0        0  ...    19801    19926    20005   20145
# China          133      171      213  ...     4814     4815     4817    4818
#
#            2/2/21  2/3/21  2/4/21  2/5/21  2/6/21  2/7/21
# Australia     909     909     909     909     909     909
# Canada      20242   20361   20486   20607   20700   20760
# China        4820    4821    4822    4822    4822    4822
#
# [3 rows x 383 columns]

# %%
sum_confirmed_global = sum_country(confirmed_global)
sum_confirmed_global
# Out:
#            1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Australia        0        0        0        0        4        5        5
# Canada           0        0        0        0        1        1        2
# China          548      643      920     1406     2075     2877     5509
#
#            1/29/20  1/30/20  1/31/20  ...  1/29/21  1/30/21  1/31/21  2/1/21  \
# Australia        6        9        9  ...    28806    28811    28818   28823
# Canada           2        2        4  ...   774932   778782   782477  788197
# China         6087     8141     9802  ...    99848    99968   100063  100127
#
#            2/2/21  2/3/21  2/4/21  2/5/21  2/6/21  2/7/21
# Australia   28829   28838   28842   28848   28851   28857
# Canada     791145  794412  798394  802530  805794  809001
# China      100177  100226  100268  100318  100348  100389
#
# [3 rows x 383 columns]

# %%
sum_recovered_global = sum_country(recovered_global)
sum_recovered_global
# Out:
#            1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Australia        0        0        0        0        0        0        0
# Canada           0        0        0        0        0        0        0
# China           28       30       36       39       49       58      101
#
#            1/29/20  1/30/20  1/31/20  ...  1/29/21  1/30/21  1/31/21  2/1/21  \
# Australia        0        2        2  ...    26045    26057    26061   26064
# Canada           0        0        0  ...   701306   706285   710699  718049
# China          120      135      214  ...    92321    92622    92779   92891
#
#            2/2/21  2/3/21  2/4/21  2/5/21  2/6/21  2/7/21
# Australia   26070   26079   26080   26083   26086   26089
# Canada     722002  726258  729768  726095  729371  732688
# China       93060   93280   93459   93606   93752   93883
#
# [3 rows x 383 columns]

# %% [markdown]
# <b> Create a dataset with coordinates </b> <br>
# (after replacing the country names)

# %%
# Create a dataset with the first 4 columns (after replacing the country names with overseas territories)

coordinates = confirmed_global_renamed.iloc[:,0:4]

# Save the table to a csv file 
coordinates.to_csv("C:/Users/Agnieszka/Downloads/Datasets/Covid_temp/coordinates.csv", index=False)

coord = pd.read_csv("C:/Users/Agnieszka/Downloads/Datasets/Covid_temp/coordinates.csv")
coord.head()
# Out:
#   Province/State Country/Region       Lat       Long
# 0            NaN    Afghanistan  33.93911  67.709953
# 1            NaN        Albania  41.15330  20.168300
# 2            NaN        Algeria  28.03390   1.659600
# 3            NaN        Andorra  42.50630   1.521800
# 4            NaN         Angola -11.20270  17.873900

# %% [markdown]
# Preparation for further steps

# %%
# Prepare dataframes for further steps

def prepare (df):
    
    # remove columns and set "Country/Region" as an index
    df_short = df.drop(columns=['Province/State', 'Lat', 'Long'], axis=0).set_index("Country/Region")
    
    # Rename US to United States
    df_short.rename(index={'US':'United States'},inplace=True)
    
    # Sort index alphabetically
    df_short.sort_index(inplace=True)

    return df_short

# %%
confirmed_global_short = prepare(confirmed_global_renamed)
confirmed_global_short.tail(5)
# Out:
#                     1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Wallis and Futuna         0        0        0        0        0        0
# West Bank and Gaza        0        0        0        0        0        0
# Yemen                     0        0        0        0        0        0
# Zambia                    0        0        0        0        0        0
# Zimbabwe                  0        0        0        0        0        0
#
#                     1/28/20  1/29/20  1/30/20  1/31/20  ...  1/29/21  1/30/21  \
# Country/Region                                          ...
# Wallis and Futuna         0        0        0        0  ...        5        5
# West Bank and Gaza        0        0        0        0  ...   158168   158559
# Yemen                     0        0        0        0  ...     2120     2120
# Zambia                    0        0        0        0  ...    51624    53352
# ...

# %%
deaths_global_short = prepare(deaths_global_renamed)
deaths_global_short.tail(5)
# Out:
#                     1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Wallis and Futuna         0        0        0        0        0        0
# West Bank and Gaza        0        0        0        0        0        0
# Yemen                     0        0        0        0        0        0
# Zambia                    0        0        0        0        0        0
# Zimbabwe                  0        0        0        0        0        0
#
#                     1/28/20  1/29/20  1/30/20  1/31/20  ...  1/29/21  1/30/21  \
# Country/Region                                          ...
# Wallis and Futuna         0        0        0        0  ...        0        0
# West Bank and Gaza        0        0        0        0  ...     1823     1831
# Yemen                     0        0        0        0  ...      615      615
# Zambia                    0        0        0        0  ...      728      745
# ...

# %%
recovered_global_short = prepare(recovered_global_renamed)
recovered_global_short.tail(5)
# Out:
#                     1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Wallis and Futuna         0        0        0        0        0        0
# West Bank and Gaza        0        0        0        0        0        0
# Yemen                     0        0        0        0        0        0
# Zambia                    0        0        0        0        0        0
# Zimbabwe                  0        0        0        0        0        0
#
#                     1/28/20  1/29/20  1/30/20  1/31/20  ...  1/29/21  1/30/21  \
# Country/Region                                          ...
# Wallis and Futuna         0        0        0        0  ...        4        4
# West Bank and Gaza        0        0        0        0  ...   148140   148583
# Yemen                     0        0        0        0  ...     1425     1426
# Zambia                    0        0        0        0  ...    44133    45443
# ...

# %% [markdown]
# Countries devided into provinces

# %%
# Remove duplicates and replace values with a sum

# df = "..._short" dataframes, prepared dataset ("prepare" function)
# df_sum - "sum_..."- dataframes ("sum_country" function)

def remove_duplicates(df, df_sum):
    
    # Remove duplicates, keep only first value that will be replaced with the sum
    df_noIndex = df.reset_index()
    df_noDuplicates = df_noIndex.drop_duplicates(subset="Country/Region", keep="first")
    df_noDuplicates2 = df_noDuplicates.set_index("Country/Region")
    
    # Replace remained values with the sum of cases from each province ("sum_..."- dataframes)
    column_names = list(multiple_countries.index.values)
    for country in column_names:
        df_noDuplicates2.loc[country] = df_sum.loc[country]

    return df_noDuplicates2

# %%
confirmed_global_cleaned = remove_duplicates(confirmed_global_short, sum_confirmed_global)
#confirmed_global_cleaned.head(20)
confirmed_global_cleaned.shape
# Expected shape: (219 - number of countries, number of all columns in an actual dataframe - 4)
# Out:
# (219, 383)

# %%
deaths_global_cleaned = remove_duplicates(deaths_global_short, sum_deaths_global)
#deaths_global_cleaned.head(20)
deaths_global_cleaned.shape
# Expected shape: (219 - number of countries, number of all columns in an actual dataframe - 4)
# Out:
# (219, 383)

# %%
recovered_global_cleaned = remove_duplicates(recovered_global_short, sum_recovered_global)
#recovered_global_cleaned.head(20)
#recovered_global_cleaned.loc["Canada"]
recovered_global_cleaned.shape
# Expected shape: (219 - number of countries, number of all columns in an actual dataframe - 4)
# Out:
# (219, 383)

# %% [markdown]
# Checking if the results are correct:

# %%
# Check if the results are correct
# Example: China

# Processed (cleaned) dataset:

confirmed_global_cleaned.loc["China"].head()
deaths_global_cleaned.loc["China"]
# Out:
# 1/22/20      17
# 1/23/20      18
# 1/24/20      26
# 1/25/20      42
# 1/26/20      56
#            ...
# 2/3/21     4821
# 2/4/21     4822
# 2/5/21     4822
# 2/6/21     4822
# 2/7/21     4822
# Name: China, Length: 383, dtype: int64

# %%
# Raw dataset

mask = deaths_global["Country/Region"] == "China"
test = deaths_global[mask]
test = test.drop(["Province/State", "Lat", "Long"], axis=1).set_index("Country/Region")
test_sum = test.sum(axis=0)
test_sum
#test_sum.values
# Out:
# 1/22/20      17
# 1/23/20      18
# 1/24/20      26
# 1/25/20      42
# 1/26/20      56
#            ...
# 2/3/21     4821
# 2/4/21     4822
# 2/5/21     4822
# 2/6/21     4822
# 2/7/21     4822
# Length: 383, dtype: int64

# %%
# Check if the results for all three countries (China, Australia, Canada) are correct using a function:

# df_cleaned = cleaned dataset with overseas territories as "Country" and sum of provinces "..._cleaned " 
# df_raw = initial dataset

def test (df_cleaned, df_raw):
    
    # Raw dataset
    column_names = list(multiple_countries.index.values)   
    t = []
    for country in column_names:
        
        # Calculate sum
        mask = df_raw["Country/Region"] == country
        test = df_raw[mask]
        test = test.drop(["Province/State", "Lat", "Long"], axis=1).set_index("Country/Region")
        test_sum = test.sum(axis=0)
        #test_sum.name = "sum_dataset_raw"
        
        # Append to the list "t"
        t.append(test_sum.values)
        
    # Convert list into dataframe
    sum_raw = pd.DataFrame([t], columns=column_names).transpose()
    # Split the "0" column 
    sum_raw = pd.DataFrame(sum_raw[0].to_list(), index=multiple_countries.index.values, columns=test.columns)
        #df_test_sum = pd.DataFrame([t], columns=multiple_countries.index.values)
        #df_test_sum_end = pd.DataFrame(df_test_sum[0].to_list(), columns=test.columns , index=multiple_countries.index.values)
    #return sum_raw
    
    # Cleaned dataset
    t2 = []
    for country in column_names:
            #test_cleaned = df_cleaned.drop(columns="total", axis=0)
            #test_cleaned2 = test_cleaned.loc[country]
        # Select data for each country and append to the list "t2"
        test_cleaned = df_cleaned.loc[country]
        t2.append(test_cleaned.values)
    
    # Convert list into dataframe    
    sum_cleaned = pd.DataFrame([t2], columns=column_names).transpose()
    # Split the "0" column 
    sum_cleaned = pd.DataFrame(sum_cleaned[0].to_list(),index=multiple_countries.index.values, columns=test.columns)
    #return sum_cleaned
        
    # Merge both dataframes
    
    df_merged = pd.concat([sum_cleaned, sum_raw], keys=["sum_cleaned", "sum_raw"]).transpose()
    return df_merged
    
    
    #df["test"] = np.where(df[country] == df["sum_dataset_raw"], "correct", "error")
    #return df 

        ##if df["test"].any() == "error":
           ## print(test_cleaned2.loc[country].name + ": error")
       ## else: print(test_cleaned2.loc[country].name + ": all correct")

# %%
test = test(confirmed_global_cleaned, confirmed_global)
test
# Out:
#         sum_cleaned                   sum_raw
#           Australia  Canada   China Australia  Canada   China
# 1/22/20           0       0     548         0       0     548
# 1/23/20           0       0     643         0       0     643
# 1/24/20           0       0     920         0       0     920
# 1/25/20           0       0    1406         0       0    1406
# 1/26/20           4       1    2075         4       1    2075
# ...             ...     ...     ...       ...     ...     ...
# 2/3/21        28838  794412  100226     28838  794412  100226
# 2/4/21        28842  798394  100268     28842  798394  100268
# 2/5/21        28848  802530  100318     28848  802530  100318
# 2/6/21        28851  805794  100348     28851  805794  100348
# 2/7/21        28857  809001  100389     28857  809001  100389
#
# [383 rows x 6 columns]

# %% [markdown]
# Calculated sum for each country in "cleaned" dataset is equal to the sum in the raw dataset <br>
#  -> all functions work properly

# %% [markdown]
# <b> Save cleaned/prepared datasets to csv-files: </b>

# %%
# Cleaned datasets can be saved to csv-files: 

confirmed_global_cleaned.to_csv("C:/Users/Agnieszka/Downloads/Datasets/Covid_temp/confirmed_global_cleaned.csv")
deaths_global_cleaned.to_csv("C:/Users/Agnieszka/Downloads/Datasets/Covid_temp/deaths_global_cleaned.csv")
recovered_global_cleaned.to_csv("C:/Users/Agnieszka/Downloads/Datasets/Covid_temp/recovered_global_cleaned.csv")

# %% [markdown]
# <b> Calculate cases per day </b>
# <br>
# As row datasets include only cumulative number of cases, cases per day will be calculated

# %%
# Function to calculate cases per day 

# df -> "_cleaned" dataset

def cases_per_day (df):
    # Transpose the dataframe
    df_trans = df.transpose()
    # reset the index
    df_trans_noIndex = df_trans.reset_index()

    # Calculate cases per day 
    k = []
    i = 1
    for i in range(len(df_trans_noIndex)):
        z = df_trans_noIndex.iloc[i,1:] - df_trans_noIndex.iloc[i-1,1:]
        k.append(z)
    
    # Dataframe with results of the substraction ("k") 
    df_diff = pd.DataFrame([k]).transpose()
    
    # Dataframe with splitted values of the previous df (all values were in one column, column"0")
    df_diff_corr = pd.DataFrame(df_diff[0].to_list(), index=df_trans.index.values)
    
    # Replace first row with the initial values
    df_diff_corr.iloc[0] = df_trans.iloc[0]
    #df_diff_corr.loc["total"] = df_trans.loc["total"]
    
    return df_diff_corr
    
    ### Only for testing! - Check if "total" is equal calculated "sum"
    ## Drop the "total" row to calculate and append the sum over all rows for each column
    #df_diff_corr_drop = df_diff_corr.drop(index="total")
    #calc_sum = df_diff_corr_drop.sum(axis=0)
    
    ## Append sum & "total" again and compare the results
    #df_diff_corr_test = df_diff_corr_drop.append(calc_sum, ignore_index=True)
    #df_diff_corr_test = df_diff_corr_test.append(df_trans.loc["total"], ignore_index=True)
    
    #return df_diff_corr_test

# %%
# cpr = Cases per day
#recovered_global_cpr = cases_per_day(recovered_global_cleaned)
recovered_global_cpr
recovered_global_cpr.to_csv("C:/Users/Agnieszka/Downloads/Datasets/Covid_temp/recovered_global_cpr.csv")

# %%
#confirmed_global_cpr = cases_per_day(confirmed_global_cleaned)
confirmed_global_cpr.loc[:,"Germany"]
confirmed_global_cpr.to_csv("C:/Users/Agnieszka/Downloads/Datasets/Covid_temp/confirmed_global_cpr.csv")

# %%
#deaths_global_cpr = cases_per_day(deaths_global_cleaned)
deaths_global_cpr
#deaths_global_cpr.to_csv("C:/Users/Agnieszka/Downloads/Datasets/Covid_temp/deaths_global_cpr.csv")
# Out:
# Country/Region  Afghanistan  Albania  Algeria  Andorra  Angola  Anguilla  \
# 1/22/20                   0        0        0        0       0         0
# 1/23/20                   0        0        0        0       0         0
# 1/24/20                   0        0        0        0       0         0
# 1/25/20                   0        0        0        0       0         0
# 1/26/20                   0        0        0        0       0         0
# ...                     ...      ...      ...      ...     ...       ...
# 2/3/21                    1        6        2        1       2         0
# 2/4/21                    1       14        4        0       3         0
# 2/5/21                    0       15        5        1       1         0
# 2/6/21                    1       13        0        1       1         0
# 2/7/21                    2       14        5        1       0         0
#
# Country/Region  Antigua and Barbuda  Argentina  Armenia  Aruba  ...  Uruguay  \
# ...

# %% [markdown]
# <b> Created datasets (csv): </b> <br> <br>
# 1) Cleaned datasets (cumulative number of cases) <br>
# confirmed_global_cleaned <br>
# deaths_global_cleaned <br>
# recovered_global_cleaned <br> <br>
# 2) Dataset with calculated cases per day <br>
# confirmed_global_cpr <br>
# deaths_global_cpr <br>
# recovered_global_cpr <br> <br>
# 3) Coordinates <br>
# coordinates
